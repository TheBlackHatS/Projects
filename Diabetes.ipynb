# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("diabetes.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Pregnancies  Glucose  BP  SkinThickness  Insulin   BMI  \
# 0              6      148  72             35        0  33.6
# 1              1       85  66             29        0  26.6
# 2              8      183  64              0        0  23.3
# 3              1       89  66             23       94  28.1
# 4              0      137  40             35      168  43.1
# ..           ...      ...  ..            ...      ...   ...
# 763           10      101  76             48      180  32.9
# 764            2      122  70             27        0  36.8
# 765            5      121  72             23      112  26.2
# 766            1      126  60              0        0  30.1
# 767            1       93  70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BP  SkinThickness  Insulin   BMI  \
# 0            6      148  72             35        0  33.6
# 1            1       85  66             29        0  26.6
# 2            8      183  64              0        0  23.3
# 3            1       89  66             23       94  28.1
# 4            0      137  40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BP  SkinThickness  Insulin   BMI  \
# 763           10      101  76             48      180  32.9
# 764            2      122  70             27        0  36.8
# 765            5      121  72             23      112  26.2
# 766            1      126  60              0        0  30.1
# 767            1       93  70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample(3)
# Out:
#      Pregnancies  Glucose  BP  SkinThickness  Insulin   BMI  \
# 376            0       98  82             15       84  25.2
# 328            2      102  86             36      120  45.5
# 667           10      111  70             27        0  27.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 376                     0.299   22        0
# 328                     0.127   23        1
# 667                     0.141   40        1

# %%
#Indexes at axis=1
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BP', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
#Null Values
False==0
# Out:
# True

# %%
True==1
# Out:
# True

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose     BP  SkinThickness  Insulin    BMI  \
# 0          False    False  False          False    False  False
# 1          False    False  False          False    False  False
# 2          False    False  False          False    False  False
# 3          False    False  False          False    False  False
# 4          False    False  False          False    False  False
# ..           ...      ...    ...            ...      ...    ...
# 763        False    False  False          False    False  False
# 764        False    False  False          False    False  False
# 765        False    False  False          False    False  False
# 766        False    False  False          False    False  False
# 767        False    False  False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BP                          0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Imputation:

# %% [markdown]
# .Categorical Column==>mode/frequent
# .Continuous Column==>mean/median

# %%
# knn imputer, iterative imputer, simple imputer

# %%
#df.['DiabetesPedigreeFunction'].fillna(value=df.['DiabetesPedigreeFunction'].mean())

# %%
#df.fillna()

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BP', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#      Pregnancies  Glucose  BP  SkinThickness  Insulin   BMI  \
# 0              6      148  72             35        0  33.6
# 1              1       85  66             29        0  26.6
# 2              8      183  64              0        0  23.3
# 3              1       89  66             23       94  28.1
# 4              0      137  40             35      168  43.1
# ..           ...      ...  ..            ...      ...   ...
# 763           10      101  76             48      180  32.9
# 764            2      122  70             27        0  36.8
# 765            5      121  72             23      112  26.2
# 766            1      126  60              0        0  30.1
# 767            1       93  70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# .Descriptive Analytics
# .Null values Anslysis
# .Visualization:-Univariate(boxplot,density(histogram,kde)) , Bivariate(scatter plot), Multivariate(pair plot,heatmaps)
# .Heirarchial visualization
# .correlations/causations
# .skewness,kurtosis,moments,momentum

# %% [markdown]
# # Machine learning prerequisite
# .data=normal distribution
# .no outliers
# .same scale
# .no null values

# %% [markdown]
# .independent features==>normal distribution==>remove skewness==>transformation
# .outliers ==>zscore / iqr proximity rule(boxplot)
# .dataset==> in same scale ==>normalization, standardization
# .column(mean) = 0 ==> column is centered
# std dev = 1

# %% [markdown]
# # Scatter plot

# %%
import seaborn as sns

# %%
#sns.scatterplot()

# %%
sns.scatterplot(x='Pregnancies',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %% [markdown]
# number of weeks of pregnancies is equally distribute in range 0 to 13.

# %%
sns.scatterplot(x='Glucose',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Outcome'>

# %% [markdown]
# glucose is equally distributed in range 75 to 200

# %%
sns.scatterplot(x='BP',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='BP', ylabel='Outcome'>

# %% [markdown]
# BP is equally distributed in range 45 to 100

# %%
sns.scatterplot(x='SkinThickness',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Outcome'>

# %% [markdown]
# Skinthickness is equally distributed in range 5 to 55

# %%
sns.scatterplot(x='Insulin',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Outcome'>

# %% [markdown]
# Insulin is equally distributed in range 0 to 375.

# %%
sns.scatterplot(x='BMI',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Outcome'>

# %% [markdown]
# BMI is equally distributed in range 25 to 50

# %%
sns.scatterplot(x='DiabetesPedigreeFunction',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Outcome'>

# %% [markdown]
# DiabetesPedigreeFunction is equally distributed in range 0 to 1.25

# %%
sns.scatterplot(x='Age',y='Outcome',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Outcome'>

# %% [markdown]
# Age is equally distributed in range 20 to 60

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose        BP  SkinThickness  \
# Pregnancies                  1.000000  0.129459  0.141282      -0.081672
# Glucose                      0.129459  1.000000  0.152590       0.057328
# BP                           0.141282  0.152590  1.000000       0.207371
# SkinThickness               -0.081672  0.057328  0.207371       1.000000
# Insulin                     -0.073535  0.331357  0.088933       0.436783
# BMI                          0.017683  0.221071  0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337  0.041265       0.183928
# Age                          0.544341  0.263514  0.239528      -0.113970
# Outcome                      0.221898  0.466581  0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# ...

# %%
df.corr()['Outcome'].sort_values()
# Out:
# BP                          0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# DiabetesPedigreeFunction    0.173844
# Pregnancies                 0.221898
# Age                         0.238356
# BMI                         0.292695
# Glucose                     0.466581
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# # correlation using heatmaps

# %%
import matplotlib.pyplot as plt
#size of canvas
plt.figure(figsize=(15,7))

sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation

# %% [markdown]
# All the columns of the dataset is positively correlated with target column.
#
# .Pregnancies has 22% correlation with target column which can be considered as as a good bond.
# .Glucose has 47% correlation with target column which can be considered as a strong bond.
# .BP has 7% correlation with target column which can be considered as a weak bond.
# .SkinThickness has 7% correlation with target column which can be considered as a weak bond.
# .Insulin has 13% correlation with target column which can be considered as a weak bond.
# .BMI has 29% correlation with target column which can be considered as a good bond.
# .DiabetesFunctionPedigree has 17% correlation with target column which can be considered as a good bond.
# .Age has 24% correlation with target column which can be considered as a good bond.
#
# MAX Correlation=Glucose
# Min Correlation=SkinThickness

# %% [markdown]
# # Descriptive Statistics

# %%
round(df.describe()[1:].transpose(),2)
# Out:
#                             mean     std    min    25%     50%     75%     max
# Pregnancies                 3.85    3.37   0.00   1.00    3.00    6.00   17.00
# Glucose                   120.89   31.97   0.00  99.00  117.00  140.25  199.00
# BP                         69.11   19.36   0.00  62.00   72.00   80.00  122.00
# SkinThickness              20.54   15.95   0.00   0.00   23.00   32.00   99.00
# Insulin                    79.80  115.24   0.00   0.00   30.50  127.25  846.00
# BMI                        31.99    7.88   0.00  27.30   32.00   36.60   67.10
# DiabetesPedigreeFunction    0.47    0.33   0.08   0.24    0.37    0.63    2.42
# Age                        33.24   11.76  21.00  24.00   29.00   41.00   81.00
# Outcome                     0.35    0.48   0.00   0.00    0.00    1.00    1.00

# %%
df.describe()
# Out:
#        Pregnancies     Glucose          BP  SkinThickness     Insulin  \
# count   768.000000  768.000000  768.000000     768.000000  768.000000
# mean      3.845052  120.894531   69.105469      20.536458   79.799479
# std       3.369578   31.972618   19.355807      15.952218  115.244002
# min       0.000000    0.000000    0.000000       0.000000    0.000000
# 25%       1.000000   99.000000   62.000000       0.000000    0.000000
# 50%       3.000000  117.000000   72.000000      23.000000   30.500000
# 75%       6.000000  140.250000   80.000000      32.000000  127.250000
# max      17.000000  199.000000  122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe()[1:]
# Out:
#       Pregnancies     Glucose          BP  SkinThickness     Insulin  \
# mean     3.845052  120.894531   69.105469      20.536458   79.799479
# std      3.369578   31.972618   19.355807      15.952218  115.244002
# min      0.000000    0.000000    0.000000       0.000000    0.000000
# 25%      1.000000   99.000000   62.000000       0.000000    0.000000
# 50%      3.000000  117.000000   72.000000      23.000000   30.500000
# 75%      6.000000  140.250000   80.000000      32.000000  127.250000
# max     17.000000  199.000000  122.000000      99.000000  846.000000
#
#             BMI  DiabetesPedigreeFunction        Age   Outcome
# mean  31.992578                  0.471876  33.240885  0.348958
# std    7.884160                  0.331329  11.760232  0.476951
# min    0.000000                  0.078000  21.000000  0.000000
# 25%   27.300000                  0.243750  24.000000  0.000000
# 50%   32.000000                  0.372500  29.000000  0.000000
# ...

# %%
df.describe()[1:].transpose()
# Out:
#                                 mean         std     min       25%       50%  \
# Pregnancies                 3.845052    3.369578   0.000   1.00000    3.0000
# Glucose                   120.894531   31.972618   0.000  99.00000  117.0000
# BP                         69.105469   19.355807   0.000  62.00000   72.0000
# SkinThickness              20.536458   15.952218   0.000   0.00000   23.0000
# Insulin                    79.799479  115.244002   0.000   0.00000   30.5000
# BMI                        31.992578    7.884160   0.000  27.30000   32.0000
# DiabetesPedigreeFunction    0.471876    0.331329   0.078   0.24375    0.3725
# Age                        33.240885   11.760232  21.000  24.00000   29.0000
# Outcome                     0.348958    0.476951   0.000   0.00000    0.0000
#
#                                 75%     max
# Pregnancies                 6.00000   17.00
# Glucose                   140.25000  199.00
# BP                         80.00000  122.00
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variable Summary')
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# # Outcome of describe datasets:
#
# Shape of dataset:
# .768 rows.
# .9 column.
#
# Pregnancies:
# .Mean=3.845052
# .std=3.369578
# .max_value=17.000000
# .Min_value=0
#
# Glucose:
# .Mean=120.894531
# .std=31.972618
# .max_value=199.000000
# .Min_value=0
#
# BP:
# .Mean=69.105469
# .std=19.355807
# .max_value=122.000000
# .Min_value=0.000000
#
# SkinThickness:
# .Mean=181.567282
# .std=21.354219
# .max_value=247.000000
# .Min_value=121.800000
#
# Insulin:
# .Mean=79.799479
# .std=115.244002
# .max_value=846.000000
# .Min_value=0.000000
#
# BMI:
# .Mean=31.992578
# .std=7.884160
# .max_value=67.100000
# .Min_value=0
#
#
# DiabetesPedigreeFunction:
# .Mean=0.471876
# .std=0.331329
# .max_value=2.420000
# .Min_value=0.078000
#
# Age: this comes under categorical data
# .Max_value=81
# .Min_Value=21
# .25% data=24
# .50% data=29
# .75% data=41
#
# Outcome: this  comes under binary categoriacal data,so describe shows no valid outcome.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BP                        768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# from the above code we can have the columns datatype and memory used by dataframe.

# %% [markdown]
# # Outliers checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=14

# %%
collist
# Out:
# array(['Pregnancies', 'Glucose', 'BP', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'], dtype=object)

# %%
range(0,9)
# Out:
# range(0, 9)

# %%
len(list(range(0,len(collist))))
# Out:
# 9

# %%
range(0,len(collist))
# Out:
# range(0, 9)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Pregnancies

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BP                         -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [markdown]
# .outcomr of skewness: skewness thresold is taken +/-0.65.
# .Columns which are having skewness:
#     Pegnancies
#     BP
#     Insulin
#     DiabetesPedigreeFunction
#     Age

# %% [markdown]
# # Normal distribution curve

# %%
sns.distplot(df['Pregnancies'])
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the noramlised curve.

# %%
sns.distplot(df['Glucose'])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the noramlised curve.

# %%
sns.distplot(df['BP'])
# Out:
# <AxesSubplot:xlabel='BP', ylabel='Density'>

# %% [raw]
# The data of the column is not normalised.The building blocks is out of the noramlised curve.

# %%
sns.distplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %% [markdown]
# .The data of the column is not normalised.The building blocks is out of the noramlised curve.
# .This plot is almost bimodal.Bimodal=Two modes(most occuring frequency)

# %%
sns.distplot(df['Insulin'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %% [markdown]
# .The data of the column is not normalised.The building blocks is out of the noramlised curve.

# %%
sns.distplot(df['BMI'])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %% [markdown]
# .The data of the column is not normalised.The building blocks is out of the noramlised curve.

# %%
sns.distplot(df['DiabetesPedigreeFunction'])
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %% [markdown]
# .The data of the column is not normalised.The building blocks is out of the noramlised curve.

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# .The data of the column is not normalised.The building blocks is out of the noramlised curve.
# .The normal distributio curve of outcome is irrelevant.

# %% [markdown]
# The data distribution shows that the data is skewed.

# %% [markdown]
# # Data Cleaning

# %%
df.corr()['Outcome'].sort_values()
# Out:
# BP                          0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# DiabetesPedigreeFunction    0.173844
# Pregnancies                 0.221898
# Age                         0.238356
# BMI                         0.292695
# Glucose                     0.466581
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
delete=pd.DataFrame([['0.065068','BP','No','Alot'],['0.074752','SkinThickness','No','Alot']],
                   columns=['Correlation with Target','Column Name','Normalised','Outliers'])
delete
# Out:
#   Correlation with Target    Column Name Normalised Outliers
# 0                0.065068             BP         No     Alot
# 1                0.074752  SkinThickness         No     Alot

# %% [markdown]
# Here,we are setting thresold of correlation as +/-0.1.It is not standard the dataset demands.

# %%
df=df.drop(["BP","SkinThickness"],axis=1)

# %%
df
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 4              0      137      168  43.1                     2.288   33
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# ...

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# IQR proximity rule

# %% [markdown]
# Z-score Technique

# %%
np.abs(2)
# Out:
# 2

# %%
np.abs(-2)
# Out:
# 2

# %%
from scipy.stats import zscore

# %%
zscore(df)
# Out:
#      Pregnancies   Glucose   Insulin       BMI  DiabetesPedigreeFunction  \
# 0       0.639947  0.848324 -0.692891  0.204013                  0.468492
# 1      -0.844885 -1.123396 -0.692891 -0.684422                 -0.365061
# 2       1.233880  1.943724 -0.692891 -1.103255                  0.604397
# 3      -0.844885 -0.998208  0.123302 -0.494043                 -0.920763
# 4      -1.141852  0.504055  0.765836  1.409746                  5.484909
# ..           ...       ...       ...       ...                       ...
# 763     1.827813 -0.622642  0.870031  0.115169                 -0.908682
# 764    -0.547919  0.034598 -0.692891  0.610154                 -0.398282
# 765     0.342981  0.003301  0.279594 -0.735190                 -0.685193
# 766    -0.844885  0.159787 -0.692891 -0.240205                 -0.371101
# 767    -0.844885 -0.873019 -0.692891 -0.202129                 -0.473785
#
#           Age   Outcome
# 0    1.425995  1.365896
# 1   -0.190672 -0.732120
# ...

# %%
np.abs(zscore(df))
# Out:
#      Pregnancies   Glucose   Insulin       BMI  DiabetesPedigreeFunction  \
# 0       0.639947  0.848324  0.692891  0.204013                  0.468492
# 1       0.844885  1.123396  0.692891  0.684422                  0.365061
# 2       1.233880  1.943724  0.692891  1.103255                  0.604397
# 3       0.844885  0.998208  0.123302  0.494043                  0.920763
# 4       1.141852  0.504055  0.765836  1.409746                  5.484909
# ..           ...       ...       ...       ...                       ...
# 763     1.827813  0.622642  0.870031  0.115169                  0.908682
# 764     0.547919  0.034598  0.692891  0.610154                  0.398282
# 765     0.342981  0.003301  0.279594  0.735190                  0.685193
# 766     0.844885  0.159787  0.692891  0.240205                  0.371101
# 767     0.844885  0.873019  0.692891  0.202129                  0.473785
#
#           Age   Outcome
# 0    1.425995  1.365896
# 1    0.190672  0.732120
# ...

# %%
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (768, 7)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
#Index number
 
np.where(z>3)
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#         145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#         342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#         455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#         684, 684, 695, 706, 753], dtype=int64),
#  array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#         2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#         3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
z.iloc[9]
# Out:
# Pregnancies                 1.233880
# Glucose                     0.128489
# Insulin                     0.692891
# BMI                         4.060474
# DiabetesPedigreeFunction    0.724455
# Age                         1.766346
# Outcome                     1.365896
# Name: 9, dtype: float64

# %%
len(np.where(z>3)[0])
# Out:
# 57

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print('old dataframe',df.shape)
print('new datafrane',df_new.shape)
print('Totsl dropped rows',df.shape[0]-df_new.shape[0])
# Out:
# old dataframe (768, 7)
# new datafrane (716, 7)
# Totsl dropped rows 52

# %% [markdown]
# Percentage  data loss

# %%
loss_percent=(768-716)/768*100
print(loss_percent,'%')
# Out:
# 6.770833333333333 %

# %% [markdown]
# checking whether how much outliers are still there. if the outliers help in the testing the model or not.

# %% [markdown]
# # Model without outliers is df  and model with desired outliers is df_new1

# %% [markdown]
# Diving data in features and vectors.

# %%
df_new
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 5          0
# ..       ...
# ...

# %% [markdown]
# # Separate the Data

# %%
#Independent Column
x=df_new.iloc[:,:-1]

# %%
x
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
# [716 rows x 6 columns]

# %%
#Target
y=df_new.iloc[:,-1]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 716, dtype: int64

# %% [markdown]
# # Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.1698999 ,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
x.ndim
# Out:
# 2

# %%
#from sklearn.preprocessing import StandardScaler

#transform dataset into a standard normal distributor

#sc=StandardScaler()
#x=sc.fit_transform(x)
#x

# %%
x.mean()
# Out:
# 2.395972929679877e-15

# %%
round(-1.26*10**(-17),15)
# Out:
# -0.0

# %%
x.std()
# Out:
# 1.0

# %% [raw]
# since the outcome is only two classes we wil use binary classification model

# %%
df.Outcome.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# #  spliting the dataframe

# %%
lr=LogisticRegression()
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random state',i,'the model perform very well')
        print('at random state',i)
        print('training accuracy_score is:',round(accuracy_score(y_train,pred_train)*100,1))
        print('Testing accuracy_score is:',round(accuracy_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# At random state 51 the model perform very well
# at random state 51
# training accuracy_score is: 77.8
# Testing accuracy_score is: 77.8
#
#
# At random state 86 the model perform very well
# at random state 86
# training accuracy_score is: 77.8
# Testing accuracy_score is: 77.8
#
#
# At random state 90 the model perform very well
# at random state 90
# training accuracy_score is: 78.5
# Testing accuracy_score is: 78.5
#
#
# At random state 93 the model perform very well
# at random state 93
# training accuracy_score is: 77.8
# Testing accuracy_score is: 77.8
#
#
# At random state 127 the model perform very well
# at random state 127
# training accuracy_score is: 78.5
# Testing accuracy_score is: 78.5
#
#
# At random state 135 the model perform very well
# at random state 135
# training accuracy_score is: 77.8
# Testing accuracy_score is: 77.8
#
#
# At random state 185 the model perform very well
# at random state 185
# training accuracy_score is: 78.5
# ...

# %%
x_tain,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=90)

# %% [markdown]
# # Logistic Regression

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_train=lr.predict(x_train)

# %%
pred_test=lr.predict(x_test)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 0.6398601398601399

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.7291666666666666

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84       107
#            1       0.00      0.00      0.00        37
#
#     accuracy                           0.73       144
#    macro avg       0.37      0.49      0.42       144
# weighted avg       0.55      0.73      0.63       144

# %% [markdown]
# # cross validation score for logistic regression

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)

# %%
lss
# Out:
# 0.7291666666666666

# %%
for j in range(4,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    print(lsscore)
    lsc=lsscore.mean()
    print('At cv:',j)
    print('Cross validation score is:',lsc*100)
    print('accuracy score is:',lss*100)
    print('\n')
# Out:
# [0.75977654 0.75418994 0.76536313 0.80446927]
# At cv: 4
# Cross validation score is: 77.09497206703911
# accuracy score is: 72.91666666666666
#
#
# [0.75694444 0.75524476 0.75524476 0.81818182 0.76923077]
# At cv: 5
# Cross validation score is: 77.09693084693085
# accuracy score is: 72.91666666666666
#
#
# [0.73333333 0.79166667 0.74789916 0.74789916 0.83193277 0.78991597]
# At cv: 6
# Cross validation score is: 77.37745098039215
# accuracy score is: 72.91666666666666
#
#
# [0.72815534 0.78640777 0.73529412 0.7745098  0.73529412 0.85294118
#  0.78431373]
# At cv: 7
# Cross validation score is: 77.09880068532267
# accuracy score is: 72.91666666666666
#
#
# [0.71111111 0.8        0.72222222 0.77777778 0.75280899 0.78651685
#  0.82022472 0.80898876]
# At cv: 8
# Cross validation score is: 77.2456304619226
# accuracy score is: 72.91666666666666
#
#
# [0.725      0.8125     0.7625     0.725      0.775      0.72151899
#  0.86075949 0.78481013 0.81012658]
# At cv: 9
# ...

# %% [raw]
# since cross validation score ,accuracy score are almost same.we are heading with good approach.

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=9).mean()
print('The cv score is:',lsscore_selected,"\nthe accuracy score is:",lss)
# Out:
# The cv score is: 0.7752461322081574
# the accuracy score is: 0.7291666666666666

# %%
from sklearn.metrics import confusion_matrix

# %%
lr
# Out:
# LogisticRegression()

# %%
def model_selection(algorithm_instance,x_train,y_train,x_test,y_test):
    algorithm_instance.fit(x_train,y_train)
    model_1_pred_train=algorithm_instance.predict(x_train)
    model_1_pred_test=algorithm_instance.predict(x_test)
    print('accuracy of the training model:',accuracy_score(y_train,model_1_pred_train))
    print('accuracy of the test data:',accuracy_score(y_test,model_1_pred_test))
    print('classification report of test data:\n',classification_report(y_test,model_1_pred_test))
    print('classification report of train data:\n',classification_report(y_train,model_1_pred_train))
    print('confusion Matrix:\n',confusion_matrix(y_test,model_1_pred_test))

# %%
model_selection(lr,x_train,y_train,x_test,y_test)
# Out:
# accuracy of the training model: 0.6398601398601399
# accuracy of the test data: 0.7291666666666666
# classification report of test data:
#                precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84       107
#            1       0.00      0.00      0.00        37
#
#     accuracy                           0.73       144
#    macro avg       0.37      0.49      0.42       144
# weighted avg       0.55      0.73      0.63       144
#
# classification report of train data:
#                precision    recall  f1-score   support
#
#            0       0.64      0.99      0.78       366
#            1       0.50      0.02      0.05       206
#
#     accuracy                           0.64       572
#    macro avg       0.57      0.51      0.41       572
# weighted avg       0.59      0.64      0.51       572
#
# confusion Matrix:
#  [[105   2]
#  [ 37   0]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
model_selection(dt,x_train,y_train,x_test,y_test)
# Out:
# accuracy of the training model: 1.0
# accuracy of the test data: 0.5694444444444444
# classification report of test data:
#                precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70       107
#            1       0.22      0.27      0.24        37
#
#     accuracy                           0.57       144
#    macro avg       0.47      0.47      0.47       144
# weighted avg       0.60      0.57      0.58       144
#
# classification report of train data:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       366
#            1       1.00      1.00      1.00       206
#
#     accuracy                           1.00       572
#    macro avg       1.00      1.00      1.00       572
# weighted avg       1.00      1.00      1.00       572
#
# confusion Matrix:
#  [[72 35]
#  [27 10]]

# %% [markdown]
# # The model with the outliers:

# %% [raw]
# AUC ROC curve:

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve(area=%0.2f)'% roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operatin characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # since the model without outliers performing well.We will select the dataframe.

# %% [raw]
# Model saving :

# %%
import pickle
filename='diabetes.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [raw]
# Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'Original':a,'Predicted':predicted},index=range(len(a)))
df_com
# Out:
#      Original  Predicted
# 0           0          0
# 1           0          0
# 2           1          0
# 3           0          0
# 4           0          0
# ..        ...        ...
# 139         1          0
# 140         0          0
# 141         0          0
# 142         0          0
# 143         1          0
#
# [144 rows x 2 columns]

# %% [raw]
# we can visualize there is some error in the outcome using the above model.
